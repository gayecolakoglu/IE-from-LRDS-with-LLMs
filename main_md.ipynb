# %%
import os
from os import path
import itertools
import re
import json
import time
import requests
import logging
import pandas as pd
from modules.data_processing import load_dataset
from modules.batch_processing import split_jsonl_file, send_batch_requests, retrieve_and_process_batch_results
from modules.arrange_conf_md import get_log_directory, get_output_directory, get_data_paths_md
from modules.run_pipeline_md import test_experiment_serially, load_experiment_results
from config import MODEL_gpt_3, MODEL_gpt_4, MODEL_llama
from multiprocessing import current_process

# %% [markdown]
# ### Arrange working dirs

# %%
directory = 'vrdu2/registration-form/few_shot-splits/'
# directory = 'vrdu2/ad-buy-form/few_shot-splits/'

# Arrange logging and output dirs accordıng to model and form type
model = MODEL_llama  #MODEL_gpt_4 #  or 
log_directory = get_log_directory(directory, model) 
base_output_directory = get_output_directory(directory, model)

print("log_directory: ", log_directory)
print("base_output_directory: ", base_output_directory)

# Arrange folder and dataset dirs based on the provided main dir
folder_path, dataset_path, dtype = get_data_paths_md(directory)

print("folder_path:", folder_path)
print("dataset_path:", dataset_path)
print("dtype:", dtype)

log_file_path = path.join(log_directory, f"experiment_{current_process().pid}.log")
logging.basicConfig(level=logging.INFO,
                    format='%(asctime)s - %(levelname)s - %(message)s',
                    handlers=[
                        logging.FileHandler(log_file_path),
                        logging.StreamHandler()
                    ])

# Example logging
logging.info("Logging setup complete.")
# Out:
# 2025-02-24 11:37:15,207 - INFO - Logging setup complete.
# log_directory:  gpt4_Markdown_Llama3_outputs/reg/
# base_output_directory:  gpt4_Markdown_Llama3_outputs/reg/
# folder_path: gpt4_Markdown_outputs/reg/outputs
# dataset_path: vrdu2/registration-form/main/dataset.jsonl.gz
# dtype: reg

# %% [markdown]
# ### Create experıment confıguratıons

# %%
sample_size = 40
use_custom_ocr = False
prompt_types = ["no_schema", "few_shot", "chain_of_thought"]
example_num_options = [0, 1, 3, 5]
transformation_methods = ["layout-aware", "naive"]
chunking_method = 'fixed'
chunk_size_categories = ["max", "medium", "small"]
level_types = ["STL", "UTL"]

combinations = []
experiment_id = 0

for prompt_type, chunk_size_category, level_type in itertools.product(prompt_types, chunk_size_categories, level_types):
    if prompt_type == "no_schema":
        for transformation_method in transformation_methods:
            combination = {
                'experiment_id': experiment_id,
                'sample_size': sample_size,
                'use_custom_ocr': use_custom_ocr,
                'prompt_type': prompt_type,
                'chunk_size_category': chunk_size_category,
                'no_schema': True,
                'example_num': None,
                'transformation_method': transformation_method,
                'chunking_method': chunking_method,
                'level_type': level_type
            }
            combinations.append(combination)
            experiment_id += 1
    else:
        for example_num, transformation_method in itertools.product(example_num_options, transformation_methods):
            combination = {
                'experiment_id': experiment_id,
                'sample_size': sample_size,
                'use_custom_ocr': use_custom_ocr,
                'prompt_type': prompt_type,
                'chunk_size_category': chunk_size_category,
                'no_schema': False,
                'example_num': example_num,
                'transformation_method': transformation_method,
                'chunking_method': chunking_method,
                'level_type': level_type
            }
            combinations.append(combination)
            experiment_id += 1

# Creating a DataFrame
df = pd.DataFrame(combinations)

# Saving to CSV
csv_file_path = path.join(base_output_directory, 'all_experiment_combinations.csv')
df.to_csv(csv_file_path, index=False)

print(f"CSV file has been saved to {csv_file_path}")
# Out:
# CSV file has been saved to gpt4_Markdown_Llama3_outputs/reg/all_experiment_combinations.csv

# %% [markdown]
# ### Run pıpelıne wıth created experıments

# %% [markdown]
# ıf you already run all experıments and just wanted to contınue wıth only postprocessıng stepsi skip next 2 cell(test_experiment_serially, split_jsonl_file and send_batch_requests) and contınue wıth followıng cell(load_experiment_results)

# %%
if __name__ == "__main__":
    experiment_params = [(exp['sample_size'], exp['use_custom_ocr'], exp['prompt_type'], exp['chunk_size_category'], {
                         'example_num': exp['example_num'], 'no_schema': exp['no_schema'], 'transformation_method': exp['transformation_method'],
                         'chunking_method': exp['chunking_method'], 'level_type': exp['level_type']
                         }, exp['experiment_id']) for exp in combinations]
    output_file = os.path.join(base_output_directory, 'batches/batch_requests.jsonl')
    
    all_filename_mappings, all_output_data = test_experiment_serially(directory, base_output_directory, dataset_path, dtype, folder_path, model, experiment_params, output_file)
# Out:
# 2025-02-21 14:20:30,890 - INFO - Starting experiment with ID 0
# 2025-02-21 14:20:30,892 - INFO - Found 40 markdown files in gpt4_Markdown_outputs/reg/outputs/STL/Amendment
# 2025-02-21 14:20:30,894 - INFO - Found 40 markdown files in gpt4_Markdown_outputs/reg/outputs/STL/Dissemination
# 2025-02-21 14:20:30,897 - INFO - Found 40 markdown files in gpt4_Markdown_outputs/reg/outputs/STL/Short-Form
# 2025-02-21 14:20:44,791 - INFO - Experiment 0: Processing file 19950929_Hogan Lovells US LLP_Amendment_Amendment.md
# 2025-02-21 14:20:44,797 - INFO - Generating chunks for file 19950929_Hogan Lovells US LLP_Amendment_Amendment.md
# 2025-02-21 14:20:44,798 - INFO - Text length: 1620, Chunk size: 2958
# 2025-02-21 14:20:44,799 - INFO - Generated chunk: ```markdown U.S. Department of Justice Washington ... with length 1616
# 2025-02-21 14:20:44,801 - INFO - Generated 1 chunks with total text length 1616
# 2025-02-21 14:20:44,802 - INFO - Generated 1 chunks with total prompt token size 276
# 2025-02-21 14:20:45,809 - INFO - HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-21 14:20:45,821 - INFO - Raw Model output: {
# "file_date": "1945-09-29",
# "foreign_principle_name": ["Government of Haiti", "Embassy of Japan"],
# "registrant_name": "Hogan & Hartson",
# "registration_num": "2244",
# "signer_name": "BESSIE O. HOUCK",
# "signer_title": "Notary Public"
# }
# 2025-02-21 14:20:45,823 - INFO - Extracted Info List: [{'file_date': '1945-09-29', 'foreign_principle_name': ['Government of Haiti', 'Embassy of Japan'], 'registrant_name': 'Hogan & Hartson', 'registration_num': '2244', 'signer_name': 'BESSIE O. HOUCK', 'signer_title': 'Notary Public'}]
# 2025-02-21 14:20:45,825 - INFO - Processing annotations for file: 19950929_Hogan Lovells US LLP_Amendment_Amendment.pdf
# 2025-02-21 14:20:45,829 - INFO - Experiment 0: Processing file 19830401_Bermuda Tourism Authority_Amendment_Amendment.md
# 2025-02-21 14:20:45,836 - INFO - Generating chunks for file 19830401_Bermuda Tourism Authority_Amendment_Amendment.md
# 2025-02-21 14:20:45,838 - INFO - Text length: 1714, Chunk size: 2958
# 2025-02-21 14:20:45,839 - INFO - Generated chunk: ```markdown 1. Name of Registrant: Bermuda Departm... with length 1699
# 2025-02-21 14:20:45,842 - INFO - Generated 1 chunks with total text length 1699
# 2025-02-21 14:20:45,844 - INFO - Generated 1 chunks with total prompt token size 282
# RAW PRED: [{'file_date': '1945-09-29', 'foreign_principle_name': ['Government of Haiti', 'Embassy of Japan'], 'registrant_name': 'Hogan & Hartson', 'registration_num': '2244', 'signer_name': 'BESSIE O. HOUCK', 'signer_title': 'Notary Public'}]
#
# FLAT PRED:  [{'file_date': '1945-09-29', 'foreign_principle_name': ('Government of Haiti', 'Embassy of Japan'), 'registrant_name': 'Hogan & Hartson', 'registration_num': '2244', 'signer_name': 'BESSIE O. HOUCK', 'signer_title': 'Notary Public'}]
#
# Reconciled PRED:  {'file_date': '1945-09-29', 'foreign_principle_name': ('Embassy of Japan', 'Government of Haiti'), 'registrant_name': 'Hogan & Hartson', 'registration_num': '2244', 'signer_name': 'BESSIE O. HOUCK', 'signer_title': 'Notary Public'}
#
# initial_pred: {'file_date': '1945-09-29', 'foreign_principle_name': ('Embassy of Japan', 'Government of Haiti'), 'registrant_name': 'Hogan & Hartson', 'registration_num': '2244', 'signer_name': 'BESSIE O. HOUCK', 'signer_title': 'Notary Public'}
#
# mapped_pred: {'file_date': '1945-09-29', 'foreign_principle_name': ('Embassy of Japan', 'Government of Haiti'), 'registrant_name': 'Hogan & Hartson', 'registration_num': '2244', 'signer_name': 'BESSIE O. HOUCK', 'signer_title': 'Notary Public'}
#
# cleaned_pred: {'file_date': '1945-09-29', 'foreign_principle_name': ('Embassy Of Japan', 'Government Of Haiti'), 'registrant_name': 'Hogan & Hartson', 'registration_num': '2244', 'signer_name': 'Bessie O. Houck', 'signer_title': 'notary public'}
#
# ground_truth_value: {'file_date': ['September\n.19 45 29th\nday of'], 'foreign_principle_name': '', 'registrant_name': ['Hogan & Hartson'], 'registration_num': ['2244'], 'signer_name': '', 'signer_title': ''}
# \cleaned_gt_value: {'file_date': ['september .19 45 29th day of'], 'foreign_principle_name': '', 'registrant_name': ['Hogan & Hartson'], 'registration_num': ['2244'], 'signer_name': '', 'signer_title': ''}
#
# Comparison result for pred_value: 1945-09-29 and gt_value: ['September\n.19 45 29th\nday of'] is => False
#
# Comparison result for pred_value: Hogan & Hartson and gt_value: ['Hogan & Hartson'] is => True
#
# Comparison result for pred_value: 2244 and gt_value: ['2244'] is => True
#
#  SCHEMA METRIC:  defaultdict(<function calculate_schema_metrics.<locals>.<lambda> at 0x7f49e7c30400>, {'file_date': {'tp': 0, 'fp': 1, 'fn': 0}, 'registrant_name': {'tp': 1, 'fp': 0, 'fn': 0}, 'registration_num': {'tp': 1, 'fp': 0, 'fn': 0}})
#
# Comparison result for pred_value: 1945-09-29 and gt_value: ['September\n.19 45 29th\nday of'] is => False
#
# Comparison result for pred_value: Hogan & Hartson and gt_value: ['Hogan & Hartson'] is => True
#
# Comparison result for pred_value: 2244 and gt_value: ['2244'] is => True
#
#  SCHEMA METRIC:  defaultdict(<function calculate_schema_metrics.<locals>.<lambda> at 0x7f49e7c30400>, {'file_date': {'tp': 0, 'fp': 1, 'fn': 0}, 'registrant_name': {'tp': 1, 'fp': 0, 'fn': 0}, 'registration_num': {'tp': 1, 'fp': 0, 'fn': 0}})
#
# Comparison result for pred_value: 1945-09-29 and gt_value: ['september .19 45 29th day of'] is => False
#
# Comparison result for pred_value: Hogan & Hartson and gt_value: ['Hogan & Hartson'] is => True
#
# Comparison result for pred_value: 2244 and gt_value: ['2244'] is => True
#
#  SCHEMA METRIC:  defaultdict(<function calculate_schema_metrics.<locals>.<lambda> at 0x7f49e7c30400>, {'file_date': {'tp': 0, 'fp': 1, 'fn': 0}, 'registrant_name': {'tp': 1, 'fp': 0, 'fn': 0}, 'registration_num': {'tp': 1, 'fp': 0, 'fn': 0}})
#
# initial_pred: {'file_date': '1945-09-29', 'foreign_principle_name': ('Embassy of Japan', 'Government of Haiti'), 'registrant_name': 'Hogan & Hartson', 'registration_num': '2244', 'signer_name': 'BESSIE O. HOUCK', 'signer_title': 'Notary Public'}
#
# mapped_pred: {'file_date': '1945-09-29', 'foreign_principle_name': ('Embassy of Japan', 'Government of Haiti'), 'registrant_name': 'Hogan & Hartson', 'registration_num': '2244', 'signer_name': 'BESSIE O. HOUCK', 'signer_title': 'Notary Public'}
#
# cleaned_pred: {'file_date': '1945-09-29', 'foreign_principle_name': ('Embassy Of Japan', 'Government Of Haiti'), 'registrant_name': 'Hogan & Hartson', 'registration_num': '2244', 'signer_name': 'Bessie O. Houck', 'signer_title': 'notary public'}
#
# ground_truth_value: {'file_date': ['September\n.19 45 29th\nday of'], 'foreign_principle_name': '', 'registrant_name': ['Hogan & Hartson'], 'registration_num': ['2244'], 'signer_name': '', 'signer_title': ''}
# \cleaned_gt_value: {'file_date': ['september .19 45 29th day of'], 'foreign_principle_name': '', 'registrant_name': ['Hogan & Hartson'], 'registration_num': ['2244'], 'signer_name': '', 'signer_title': ''}
#
# Comparison result for pred_value: 1945-09-29 and gt_value: ['September\n.19 45 29th\nday of'] is => False
#
# Comparison result for pred_value: Hogan & Hartson and gt_value: ['Hogan & Hartson'] is => True
#
# Comparison result for pred_value: 2244 and gt_value: ['2244'] is => True
#
#  SCHEMA METRIC:  defaultdict(<function calculate_schema_metrics.<locals>.<lambda> at 0x7f49e7c30400>, {'file_date': {'tp': 0, 'fp': 1, 'fn': 0}, 'registrant_name': {'tp': 1, 'fp': 0, 'fn': 0}, 'registration_num': {'tp': 1, 'fp': 0, 'fn': 0}})
#
# Comparison result for pred_value: 1945-09-29 and gt_value: ['September\n.19 45 29th\nday of'] is => False
#
# Comparison result for pred_value: Hogan & Hartson and gt_value: ['Hogan & Hartson'] is => True
#
# Comparison result for pred_value: 2244 and gt_value: ['2244'] is => True
#
#  SCHEMA METRIC:  defaultdict(<function calculate_schema_metrics.<locals>.<lambda> at 0x7f49e7c30400>, {'file_date': {'tp': 0, 'fp': 1, 'fn': 0}, 'registrant_name': {'tp': 1, 'fp': 0, 'fn': 0}, 'registration_num': {'tp': 1, 'fp': 0, 'fn': 0}})
#
# Comparison result for pred_value: 1945-09-29 and gt_value: ['september .19 45 29th day of'] is => False
#
# Comparison result for pred_value: Hogan & Hartson and gt_value: ['Hogan & Hartson'] is => True
#
# Comparison result for pred_value: 2244 and gt_value: ['2244'] is => True
#
#  SCHEMA METRIC:  defaultdict(<function calculate_schema_metrics.<locals>.<lambda> at 0x7f49e7c30400>, {'file_date': {'tp': 0, 'fp': 1, 'fn': 0}, 'registrant_name': {'tp': 1, 'fp': 0, 'fn': 0}, 'registration_num': {'tp': 1, 'fp': 0, 'fn': 0}})
#
# initial_pred: {'file_date': '1945-09-29', 'foreign_principle_name': ('Embassy of Japan', 'Government of Haiti'), 'registrant_name': 'Hogan & Hartson', 'registration_num': '2244', 'signer_name': 'BESSIE O. HOUCK', 'signer_title': 'Notary Public'}
#
# mapped_pred: {'file_date': '1945-09-29', 'foreign_principle_name': ('Embassy of Japan', 'Government of Haiti'), 'registrant_name': 'Hogan & Hartson', 'registration_num': '2244', 'signer_name': 'BESSIE O. HOUCK', 'signer_title': 'Notary Public'}
#
# cleaned_pred: {'file_date': '1945-09-29', 'foreign_principle_name': ('Embassy Of Japan', 'Government Of Haiti'), 'registrant_name': 'Hogan & Hartson', 'registration_num': '2244', 'signer_name': 'Bessie O. Houck', 'signer_title': 'notary public'}
#
# ground_truth_value: {'file_date': ['September\n.19 45 29th\nday of'], 'foreign_principle_name': '', 'registrant_name': ['Hogan & Hartson'], 'registration_num': ['2244'], 'signer_name': '', 'signer_title': ''}
# \cleaned_gt_value: {'file_date': ['september .19 45 29th day of'], 'foreign_principle_name': '', 'registrant_name': ['Hogan & Hartson'], 'registration_num': ['2244'], 'signer_name': '', 'signer_title': ''}
#
# Comparison result for pred_value: 1945-09-29 and gt_value: ['September\n.19 45 29th\nday of'] is => False
#
# Comparison result for pred_value: Hogan & Hartson and gt_value: ['Hogan & Hartson'] is => True
#
# Comparison result for pred_value: 2244 and gt_value: ['2244'] is => True
#
#  SCHEMA METRIC:  defaultdict(<function calculate_schema_metrics.<locals>.<lambda> at 0x7f49e7c30400>, {'file_date': {'tp': 0, 'fp': 1, 'fn': 0}, 'registrant_name': {'tp': 1, 'fp': 0, 'fn': 0}, 'registration_num': {'tp': 1, 'fp': 0, 'fn': 0}})
#
# Comparison result for pred_value: 1945-09-29 and gt_value: ['September\n.19 45 29th\nday of'] is => False
#
# Comparison result for pred_value: Hogan & Hartson and gt_value: ['Hogan & Hartson'] is => True
#
# Comparison result for pred_value: 2244 and gt_value: ['2244'] is => True
#
#  SCHEMA METRIC:  defaultdict(<function calculate_schema_metrics.<locals>.<lambda> at 0x7f49e7c30400>, {'file_date': {'tp': 0, 'fp': 1, 'fn': 0}, 'registrant_name': {'tp': 1, 'fp': 0, 'fn': 0}, 'registration_num': {'tp': 1, 'fp': 0, 'fn': 0}})
#
# Comparison result for pred_value: 1945-09-29 and gt_value: ['september .19 45 29th day of'] is => False
#
# Comparison result for pred_value: Hogan & Hartson and gt_value: ['Hogan & Hartson'] is => True
#
# Comparison result for pred_value: 2244 and gt_value: ['2244'] is => True
#
#  SCHEMA METRIC:  defaultdict(<function calculate_schema_metrics.<locals>.<lambda> at 0x7f49e7c30400>, {'file_date': {'tp': 0, 'fp': 1, 'fn': 0}, 'registrant_name': {'tp': 1, 'fp': 0, 'fn': 0}, 'registration_num': {'tp': 1, 'fp': 0, 'fn': 0}})
# 2025-02-21 14:20:46,424 - INFO - HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-21 14:20:46,429 - INFO - Raw Model output: {
# "file_date": "April 7, 1983",
# "foreign_principle_name": "",
# "registrant_name": "Bermuda Department of Tourism",
# "registration_num": "430",
# "signer_name": "Ronald N. Bassett",
# "signer_title": "General Manager, North America"
# }
# 2025-02-21 14:20:46,431 - INFO - Extracted Info List: [{'file_date': 'April 7, 1983', 'foreign_principle_name': '', 'registrant_name': 'Bermuda Department of Tourism', 'registration_num': '430', 'signer_name': 'Ronald N. Bassett', 'signer_title': 'General Manager, North America'}]
# 2025-02-21 14:20:46,434 - INFO - Processing annotations for file: 19830401_Bermuda Tourism Authority_Amendment_Amendment.pdf
# 2025-02-21 14:20:46,440 - INFO - Experiment 0: Processing file 19760201_Italian Government Tourist Board (ENIT), Los Angeles_Amendment_Amendment.md
# 2025-02-21 14:20:46,462 - INFO - Generating chunks for file 19760201_Italian Government Tourist Board (ENIT), Los Angeles_Amendment_Amendment.md
# 2025-02-21 14:20:46,464 - INFO - Text length: 3975, Chunk size: 2958
# 2025-02-21 14:20:46,465 - INFO - Generated chunk: ```markdown UNITED STATES DEPARTMENT OF JUSTICE WA... with length 3927
# 2025-02-21 14:20:46,467 - INFO - Generated 1 chunks with total text length 3927
# 2025-02-21 14:20:46,469 - INFO - Generated 1 chunks with total prompt token size 619
# RAW PRED: [{'file_date': 'April 7, 1983', 'foreign_principle_name': '', 'registrant_name': 'Bermuda Department of Tourism', 'registration_num': '430', 'signer_name': 'Ronald N. Bassett', 'signer_title': 'General Manager, North America'}]
#
# FLAT PRED:  [{'file_date': 'April 7, 1983', 'foreign_principle_name': '', 'registrant_name': 'Bermuda Department of Tourism', 'registration_num': '430', 'signer_name': 'Ronald N. Bassett', 'signer_title': 'General Manager, North America'}]
#
# Reconciled PRED:  {'file_date': 'April 7, 1983', 'foreign_principle_name': '', 'registrant_name': 'Bermuda Department of Tourism', 'registration_num': '430', 'signer_name': 'Ronald N. Bassett', 'signer_title': 'General Manager, North America'}
#
# initial_pred: {'file_date': 'April 7, 1983', 'foreign_principle_name': '', 'registrant_name': 'Bermuda Department of Tourism', 'registration_num': '430', 'signer_name': 'Ronald N. Bassett', 'signer_title': 'General Manager, North America'}
#
# mapped_pred: {'file_date': 'April 7, 1983', 'foreign_principle_name': '', 'registrant_name': 'Bermuda Department of Tourism', 'registration_num': '430', 'signer_name': 'Ronald N. Bassett', 'signer_title': 'General Manager, North America'}
#
# cleaned_pred: {'file_date': '1983-04-07', 'foreign_principle_name': '', 'registrant_name': 'Bermuda Department Of Tourism', 'registration_num': '430', 'signer_name': 'Ronald N. Bassett', 'signer_title': 'general manager, north america'}
#
# ground_truth_value: {'file_date': ['york\nZa\n1983\nday of\nApril'], 'foreign_principle_name': '', 'registrant_name': ['Bermuda Department of Tourism'], 'registration_num': ['430'], 'signer_name': ['(Ronald N. Bassett )'], 'signer_title': ['General Manager, North America']}
# \cleaned_gt_value: {'file_date': ['york za 1983 day of april'], 'foreign_principle_name': '', 'registrant_name': ['Bermuda Department Of Tourism'], 'registration_num': ['430'], 'signer_name': ['(ronald N. Bassett )'], 'signer_title': ['general manager, north america']}
#
# Comparison result for pred_value: April 7, 1983 and gt_value: ['york\nZa\n1983\nday of\nApril'] is => False
#
# Comparison result for pred_value: Bermuda Department of Tourism and gt_value: ['Bermuda Department of Tourism'] is => True
#
# Comparison result for pred_value: 430 and gt_value: ['430'] is => True
#
# Comparison result for pred_value: Ronald N. Bassett and gt_value: ['(Ronald N. Bassett )'] is => False
#
# Comparison result for pred_value: General Manager, North America and gt_value: ['General Manager, North America'] is => True
#
#  SCHEMA METRIC:  defaultdict(<function calculate_schema_metrics.<locals>.<lambda> at 0x7f49e7c300e0>, {'file_date': {'tp': 0, 'fp': 1, 'fn': 0}, 'registrant_name': {'tp': 1, 'fp': 0, 'fn': 0}, 'registration_num': {'tp': 1, 'fp': 0, 'fn': 0}, 'signer_name': {'tp': 0, 'fp': 1, 'fn': 0}, 'signer_title': {'tp': 1, 'fp': 0, 'fn': 0}})
#
# Comparison result for pred_value: April 7, 1983 and gt_value: ['york\nZa\n1983\nday of\nApril'] is => False
#
# Comparison result for pred_value: Bermuda Department of Tourism and gt_value: ['Bermuda Department of Tourism'] is => True
#
# Comparison result for pred_value: 430 and gt_value: ['430'] is => True
#
# Comparison result for pred_value: Ronald N. Bassett and gt_value: ['(Ronald N. Bassett )'] is => False
#
# Comparison result for pred_value: General Manager, North America and gt_value: ['General Manager, North America'] is => True
#
#  SCHEMA METRIC:  defaultdict(<function calculate_schema_metrics.<locals>.<lambda> at 0x7f49e7c300e0>, {'file_date': {'tp': 0, 'fp': 1, 'fn': 0}, 'registrant_name': {'tp': 1, 'fp': 0, 'fn': 0}, 'registration_num': {'tp': 1, 'fp': 0, 'fn': 0}, 'signer_name': {'tp': 0, 'fp': 1, 'fn': 0}, 'signer_title': {'tp': 1, 'fp': 0, 'fn': 0}})
#
# Comparison result for pred_value: 1983-04-07 and gt_value: ['york za 1983 day of april'] is => False
#
# Comparison result for pred_value: Bermuda Department Of Tourism and gt_value: ['Bermuda Department Of Tourism'] is => True
#
# Comparison result for pred_value: 430 and gt_value: ['430'] is => True
#
# Comparison result for pred_value: Ronald N. Bassett and gt_value: ['(ronald N. Bassett )'] is => False
#
# Comparison result for pred_value: general manager, north america and gt_value: ['general manager, north america'] is => True
#
#  SCHEMA METRIC:  defaultdict(<function calculate_schema_metrics.<locals>.<lambda> at 0x7f49e7c300e0>, {'file_date': {'tp': 0, 'fp': 1, 'fn': 0}, 'registrant_name': {'tp': 1, 'fp': 0, 'fn': 0}, 'registration_num': {'tp': 1, 'fp': 0, 'fn': 0}, 'signer_name': {'tp': 0, 'fp': 1, 'fn': 0}, 'signer_title': {'tp': 1, 'fp': 0, 'fn': 0}})
#
# initial_pred: {'file_date': 'April 7, 1983', 'foreign_principle_name': '', 'registrant_name': 'Bermuda Department of Tourism', 'registration_num': '430', 'signer_name': 'Ronald N. Bassett', 'signer_title': 'General Manager, North America'}
#
# mapped_pred: {'file_date': 'April 7, 1983', 'foreign_principle_name': '', 'registrant_name': 'Bermuda Department of Tourism', 'registration_num': '430', 'signer_name': 'Ronald N. Bassett', 'signer_title': 'General Manager, North America'}
#
# cleaned_pred: {'file_date': '1983-04-07', 'foreign_principle_name': '', 'registrant_name': 'Bermuda Department Of Tourism', 'registration_num': '430', 'signer_name': 'Ronald N. Bassett', 'signer_title': 'general manager, north america'}
#
# ground_truth_value: {'file_date': ['york\nZa\n1983\nday of\nApril'], 'foreign_principle_name': '', 'registrant_name': ['Bermuda Department of Tourism'], 'registration_num': ['430'], 'signer_name': ['(Ronald N. Bassett )'], 'signer_title': ['General Manager, North America']}
# \cleaned_gt_value: {'file_date': ['york za 1983 day of april'], 'foreign_principle_name': '', 'registrant_name': ['Bermuda Department Of Tourism'], 'registration_num': ['430'], 'signer_name': ['(ronald N. Bassett )'], 'signer_title': ['general manager, north america']}
#
# Comparison result for pred_value: April 7, 1983 and gt_value: ['york\nZa\n1983\nday of\nApril'] is => False
#
# Comparison result for pred_value: Bermuda Department of Tourism and gt_value: ['Bermuda Department of Tourism'] is => True
#
# Comparison result for pred_value: 430 and gt_value: ['430'] is => True
#
# Comparison result for pred_value: Ronald N. Bassett and gt_value: ['(Ronald N. Bassett )'] is => False
#
# Comparison result for pred_value: General Manager, North America and gt_value: ['General Manager, North America'] is => True
#
#  SCHEMA METRIC:  defaultdict(<function calculate_schema_metrics.<locals>.<lambda> at 0x7f49e7c300e0>, {'file_date': {'tp': 0, 'fp': 1, 'fn': 0}, 'registrant_name': {'tp': 1, 'fp': 0, 'fn': 0}, 'registration_num': {'tp': 1, 'fp': 0, 'fn': 0}, 'signer_name': {'tp': 0, 'fp': 1, 'fn': 0}, 'signer_title': {'tp': 1, 'fp': 0, 'fn': 0}})
#
# Comparison result for pred_value: April 7, 1983 and gt_value: ['york\nZa\n1983\nday of\nApril'] is => False
#
# Comparison result for pred_value: Bermuda Department of Tourism and gt_value: ['Bermuda Department of Tourism'] is => True
#
# Comparison result for pred_value: 430 and gt_value: ['430'] is => True
#
# Comparison result for pred_value: Ronald N. Bassett and gt_value: ['(Ronald N. Bassett )'] is => False
#
# Comparison result for pred_value: General Manager, North America and gt_value: ['General Manager, North America'] is => True
#
#  SCHEMA METRIC:  defaultdict(<function calculate_schema_metrics.<locals>.<lambda> at 0x7f49e7c300e0>, {'file_date': {'tp': 0, 'fp': 1, 'fn': 0}, 'registrant_name': {'tp': 1, 'fp': 0, 'fn': 0}, 'registration_num': {'tp': 1, 'fp': 0, 'fn': 0}, 'signer_name': {'tp': 0, 'fp': 1, 'fn': 0}, 'signer_title': {'tp': 1, 'fp': 0, 'fn': 0}})
#
# Comparison result for pred_value: 1983-04-07 and gt_value: ['york za 1983 day of april'] is => False
#
# Comparison result for pred_value: Bermuda Department Of Tourism and gt_value: ['Bermuda Department Of Tourism'] is => True
#
# Comparison result for pred_value: 430 and gt_value: ['430'] is => True
#
# Comparison result for pred_value: Ronald N. Bassett and gt_value: ['(ronald N. Bassett )'] is => False
#
# Comparison result for pred_value: general manager, north america and gt_value: ['general manager, north america'] is => True
#
#  SCHEMA METRIC:  defaultdict(<function calculate_schema_metrics.<locals>.<lambda> at 0x7f49e7c300e0>, {'file_date': {'tp': 0, 'fp': 1, 'fn': 0}, 'registrant_name': {'tp': 1, 'fp': 0, 'fn': 0}, 'registration_num': {'tp': 1, 'fp': 0, 'fn': 0}, 'signer_name': {'tp': 0, 'fp': 1, 'fn': 0}, 'signer_title': {'tp': 1, 'fp': 0, 'fn': 0}})
#
# initial_pred: {'file_date': 'April 7, 1983', 'foreign_principle_name': '', 'registrant_name': 'Bermuda Department of Tourism', 'registration_num': '430', 'signer_name': 'Ronald N. Bassett', 'signer_title': 'General Manager, North America'}
#
# mapped_pred: {'file_date': 'April 7, 1983', 'foreign_principle_name': '', 'registrant_name': 'Bermuda Department of Tourism', 'registration_num': '430', 'signer_name': 'Ronald N. Bassett', 'signer_title': 'General Manager, North America'}
#
# cleaned_pred: {'file_date': '1983-04-07', 'foreign_principle_name': '', 'registrant_name': 'Bermuda Department Of Tourism', 'registration_num': '430', 'signer_name': 'Ronald N. Bassett', 'signer_title': 'general manager, north america'}
#
# ground_truth_value: {'file_date': ['york\nZa\n1983\nday of\nApril'], 'foreign_principle_name': '', 'registrant_name': ['Bermuda Department of Tourism'], 'registration_num': ['430'], 'signer_name': ['(Ronald N. Bassett )'], 'signer_title': ['General Manager, North America']}
# \cleaned_gt_value: {'file_date': ['york za 1983 day of april'], 'foreign_principle_name': '', 'registrant_name': ['Bermuda Department Of Tourism'], 'registration_num': ['430'], 'signer_name': ['(ronald N. Bassett )'], 'signer_title': ['general manager, north america']}
#
# Comparison result for pred_value: April 7, 1983 and gt_value: ['york\nZa\n1983\nday of\nApril'] is => False
#
# Comparison result for pred_value: Bermuda Department of Tourism and gt_value: ['Bermuda Department of Tourism'] is => True
#
# Comparison result for pred_value: 430 and gt_value: ['430'] is => True
#
# Comparison result for pred_value: Ronald N. Bassett and gt_value: ['(Ronald N. Bassett )'] is => True
#
# Comparison result for pred_value: General Manager, North America and gt_value: ['General Manager, North America'] is => True
#
#  SCHEMA METRIC:  defaultdict(<function calculate_schema_metrics.<locals>.<lambda> at 0x7f49e7c300e0>, {'file_date': {'tp': 0, 'fp': 1, 'fn': 0}, 'registrant_name': {'tp': 1, 'fp': 0, 'fn': 0}, 'registration_num': {'tp': 1, 'fp': 0, 'fn': 0}, 'signer_name': {'tp': 1, 'fp': 0, 'fn': 0}, 'signer_title': {'tp': 1, 'fp': 0, 'fn': 0}})
#
# Comparison result for pred_value: April 7, 1983 and gt_value: ['york\nZa\n1983\nday of\nApril'] is => False
#
# Comparison result for pred_value: Bermuda Department of Tourism and gt_value: ['Bermuda Department of Tourism'] is => True
#
# Comparison result for pred_value: 430 and gt_value: ['430'] is => True
#
# Comparison result for pred_value: Ronald N. Bassett and gt_value: ['(Ronald N. Bassett )'] is => True
#
# Comparison result for pred_value: General Manager, North America and gt_value: ['General Manager, North America'] is => True
#
#  SCHEMA METRIC:  defaultdict(<function calculate_schema_metrics.<locals>.<lambda> at 0x7f49e7c300e0>, {'file_date': {'tp': 0, 'fp': 1, 'fn': 0}, 'registrant_name': {'tp': 1, 'fp': 0, 'fn': 0}, 'registration_num': {'tp': 1, 'fp': 0, 'fn': 0}, 'signer_name': {'tp': 1, 'fp': 0, 'fn': 0}, 'signer_title': {'tp': 1, 'fp': 0, 'fn': 0}})
#
# Comparison result for pred_value: 1983-04-07 and gt_value: ['york za 1983 day of april'] is => False
#
# Comparison result for pred_value: Bermuda Department Of Tourism and gt_value: ['Bermuda Department Of Tourism'] is => True
#
# Comparison result for pred_value: 430 and gt_value: ['430'] is => True
#
# Comparison result for pred_value: Ronald N. Bassett and gt_value: ['(ronald N. Bassett )'] is => True
#
# Comparison result for pred_value: general manager, north america and gt_value: ['general manager, north america'] is => True
#
#  SCHEMA METRIC:  defaultdict(<function calculate_schema_metrics.<locals>.<lambda> at 0x7f49e7c300e0>, {'file_date': {'tp': 0, 'fp': 1, 'fn': 0}, 'registrant_name': {'tp': 1, 'fp': 0, 'fn': 0}, 'registration_num': {'tp': 1, 'fp': 0, 'fn': 0}, 'signer_name': {'tp': 1, 'fp': 0, 'fn': 0}, 'signer_title': {'tp': 1, 'fp': 0, 'fn': 0}})
# 2025-02-21 14:20:46,927 - INFO - HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-21 14:20:46,932 - INFO - Raw Model output: {
# "file_date": "",
# "foreign_principle_name": "Italian Government",
# "registrant_name": "Italian Government Travel Office-E.N.I.T.",
# "registration_num": "#1884",
# "signer_name": "",
# "signer_title": ""
# }
# 2025-02-21 14:20:46,934 - INFO - Extracted Info List: [{'file_date': '', 'foreign_principle_name': 'Italian Government', 'registrant_name': 'Italian Government Travel Office-E.N.I.T.', 'registration_num': '#1884', 'signer_name': '', 'signer_title': ''}]
# 2025-02-21 14:20:46,936 - INFO - Processing annotations for file: 19760201_Italian Government Tourist Board (ENIT), Los Angeles_Amendment_Amendment.pdf
# 2025-02-21 14:20:46,940 - INFO - Experiment 0: Processing file 19961018_DLA Piper US LLP_Amendment_Amendment.md
# 2025-02-21 14:20:46,953 - INFO - Generating chunks for file 19961018_DLA Piper US LLP_Amendment_Amendment.md
# 2025-02-21 14:20:46,955 - INFO - Text length: 2173, Chunk size: 2958
# 2025-02-21 14:20:46,957 - INFO - Generated chunk: ```markdown 1. Name of Registrant Verner, Liipfert... with length 2150
# 2025-02-21 14:20:46,958 - INFO - Generated 1 chunks with total text length 2150
# 2025-02-21 14:20:46,959 - INFO - Generated 1 chunks with total prompt token size 331
# RAW PRED: [{'file_date': '', 'foreign_principle_name': 'Italian Government', 'registrant_name': 'Italian Government Travel Office-E.N.I.T.', 'registration_num': '#1884', 'signer_name': '', 'signer_title': ''}]
#
# FLAT PRED:  [{'file_date': '', 'foreign_principle_name': 'Italian Government', 'registrant_name': 'Italian Government Travel Office-E.N.I.T.', 'registration_num': '#1884', 'signer_name': '', 'signer_title': ''}]
#
# Reconciled PRED:  {'file_date': '', 'foreign_principle_name': 'Italian Government', 'registrant_name': 'Italian Government Travel Office-E.N.I.T.', 'registration_num': '#1884', 'signer_name': '', 'signer_title': ''}
#
# initial_pred: {'file_date': '', 'foreign_principle_name': 'Italian Government', 'registrant_name': 'Italian Government Travel Office-E.N.I.T.', 'registration_num': '#1884', 'signer_name': '', 'signer_title': ''}
#
# mapped_pred: {'file_date': '', 'foreign_principle_name': 'Italian Government', 'registrant_name': 'Italian Government Travel Office-E.N.I.T.', 'registration_num': '#1884', 'signer_name': '', 'signer_title': ''}
#
# cleaned_pred: {'file_date': '', 'foreign_principle_name': 'Italian Government', 'registrant_name': 'Italian Government Travel Office-e.n.i.t.', 'registration_num': '1884', 'signer_name': '', 'signer_title': ''}
#
# ground_truth_value: {'file_date': '', 'foreign_principle_name': '', 'registrant_name': ['Italian Government Travel Office-E.N.I.T\n360 Post Street, Suite 801, San Francisco, Cal.\nCal.'], 'registration_num': ['1884'], 'signer_name': '', 'signer_title': ''}
# \cleaned_gt_value: {'file_date': '', 'foreign_principle_name': '', 'registrant_name': ['Italian Government Travel Office-e.n.i.t 360 Post Street, Suite 801, San Francisco, Cal. Cal.'], 'registration_num': ['1884'], 'signer_name': '', 'signer_title': ''}
#
# Comparison result for pred_value: Italian Government Travel Office-E.N.I.T. and gt_value: ['Italian Government Travel Office-E.N.I.T\n360 Post Street, Suite 801, San Francisco, Cal.\nCal.'] is => False
#
# Comparison result for pred_value: #1884 and gt_value: ['1884'] is => False
#
#  SCHEMA METRIC:  defaultdict(<function calculate_schema_metrics.<locals>.<lambda> at 0x7f49e7c30720>, {'registrant_name': {'tp': 0, 'fp': 1, 'fn': 0}, 'registration_num': {'tp': 0, 'fp': 1, 'fn': 0}})
#
# Comparison result for pred_value: Italian Government Travel Office-E.N.I.T. and gt_value: ['Italian Government Travel Office-E.N.I.T\n360 Post Street, Suite 801, San Francisco, Cal.\nCal.'] is => False
#
# Comparison result for pred_value: #1884 and gt_value: ['1884'] is => False
#
#  SCHEMA METRIC:  defaultdict(<function calculate_schema_metrics.<locals>.<lambda> at 0x7f49e7c30720>, {'registrant_name': {'tp': 0, 'fp': 1, 'fn': 0}, 'registration_num': {'tp': 0, 'fp': 1, 'fn': 0}})
#
# Comparison result for pred_value: Italian Government Travel Office-e.n.i.t. and gt_value: ['Italian Government Travel Office-e.n.i.t 360 Post Street, Suite 801, San Francisco, Cal. Cal.'] is => False
#
# Comparison result for pred_value: 1884 and gt_value: ['1884'] is => True
#
#  SCHEMA METRIC:  defaultdict(<function calculate_schema_metrics.<locals>.<lambda> at 0x7f49e7c30720>, {'registrant_name': {'tp': 0, 'fp': 1, 'fn': 0}, 'registration_num': {'tp': 1, 'fp': 0, 'fn': 0}})
#
# initial_pred: {'file_date': '', 'foreign_principle_name': 'Italian Government', 'registrant_name': 'Italian Government Travel Office-E.N.I.T.', 'registration_num': '#1884', 'signer_name': '', 'signer_title': ''}
#
# mapped_pred: {'file_date': '', 'foreign_principle_name': 'Italian Government', 'registrant_name': 'Italian Government Travel Office-E.N.I.T.', 'registration_num': '#1884', 'signer_name': '', 'signer_title': ''}
#
# cleaned_pred: {'file_date': '', 'foreign_principle_name': 'Italian Government', 'registrant_name': 'Italian Government Travel Office-e.n.i.t.', 'registration_num': '1884', 'signer_name': '', 'signer_title': ''}
#
# ground_truth_value: {'file_date': '', 'foreign_principle_name': '', 'registrant_name': ['Italian Government Travel Office-E.N.I.T\n360 Post Street, Suite 801, San Francisco, Cal.\nCal.'], 'registration_num': ['1884'], 'signer_name': '', 'signer_title': ''}
# \cleaned_gt_value: {'file_date': '', 'foreign_principle_name': '', 'registrant_name': ['Italian Government Travel Office-e.n.i.t 360 Post Street, Suite 801, San Francisco, Cal. Cal.'], 'registration_num': ['1884'], 'signer_name': '', 'signer_title': ''}
#
# Comparison result for pred_value: Italian Government Travel Office-E.N.I.T. and gt_value: ['Italian Government Travel Office-E.N.I.T\n360 Post Street, Suite 801, San Francisco, Cal.\nCal.'] is => False
#
# Comparison result for pred_value: #1884 and gt_value: ['1884'] is => True
#
#  SCHEMA METRIC:  defaultdict(<function calculate_schema_metrics.<locals>.<lambda> at 0x7f49e7c30720>, {'registrant_name': {'tp': 0, 'fp': 1, 'fn': 0}, 'registration_num': {'tp': 1, 'fp': 0, 'fn': 0}})
#
# Comparison result for pred_value: Italian Government Travel Office-E.N.I.T. and gt_value: ['Italian Government Travel Office-E.N.I.T\n360 Post Street, Suite 801, San Francisco, Cal.\nCal.'] is => False
#
# Comparison result for pred_value: #1884 and gt_value: ['1884'] is => True
#
#  SCHEMA METRIC:  defaultdict(<function calculate_schema_metrics.<locals>.<lambda> at 0x7f49e7c30720>, {'registrant_name': {'tp': 0, 'fp': 1, 'fn': 0}, 'registration_num': {'tp': 1, 'fp': 0, 'fn': 0}})
#
# Comparison result for pred_value: Italian Government Travel Office-e.n.i.t. and gt_value: ['Italian Government Travel Office-e.n.i.t 360 Post Street, Suite 801, San Francisco, Cal. Cal.'] is => False
#
# Comparison result for pred_value: 1884 and gt_value: ['1884'] is => True
#
#  SCHEMA METRIC:  defaultdict(<function calculate_schema_metrics.<locals>.<lambda> at 0x7f49e7c30720>, {'registrant_name': {'tp': 0, 'fp': 1, 'fn': 0}, 'registration_num': {'tp': 1, 'fp': 0, 'fn': 0}})
#
# initial_pred: {'file_date': '', 'foreign_principle_name': 'Italian Government', 'registrant_name': 'Italian Government Travel Office-E.N.I.T.', 'registration_num': '#1884', 'signer_name': '', 'signer_title': ''}
#
# mapped_pred: {'file_date': '', 'foreign_principle_name': 'Italian Government', 'registrant_name': 'Italian Government Travel Office-E.N.I.T.', 'registration_num': '#1884', 'signer_name': '', 'signer_title': ''}
#
# cleaned_pred: {'file_date': '', 'foreign_principle_name': 'Italian Government', 'registrant_name': 'Italian Government Travel Office-e.n.i.t.', 'registration_num': '1884', 'signer_name': '', 'signer_title': ''}
#
# ground_truth_value: {'file_date': '', 'foreign_principle_name': '', 'registrant_name': ['Italian Government Travel Office-E.N.I.T\n360 Post Street, Suite 801, San Francisco, Cal.\nCal.'], 'registration_num': ['1884'], 'signer_name': '', 'signer_title': ''}
# \cleaned_gt_value: {'file_date': '', 'foreign_principle_name': '', 'registrant_name': ['Italian Government Travel Office-e.n.i.t 360 Post Street, Suite 801, San Francisco, Cal. Cal.'], 'registration_num': ['1884'], 'signer_name': '', 'signer_title': ''}
#
# Comparison result for pred_value: Italian Government Travel Office-E.N.I.T. and gt_value: ['Italian Government Travel Office-E.N.I.T\n360 Post Street, Suite 801, San Francisco, Cal.\nCal.'] is => False
#
# Comparison result for pred_value: #1884 and gt_value: ['1884'] is => True
#
#  SCHEMA METRIC:  defaultdict(<function calculate_schema_metrics.<locals>.<lambda> at 0x7f49e7c30720>, {'registrant_name': {'tp': 0, 'fp': 1, 'fn': 0}, 'registration_num': {'tp': 1, 'fp': 0, 'fn': 0}})
#
# Comparison result for pred_value: Italian Government Travel Office-E.N.I.T. and gt_value: ['Italian Government Travel Office-E.N.I.T\n360 Post Street, Suite 801, San Francisco, Cal.\nCal.'] is => False
#
# Comparison result for pred_value: #1884 and gt_value: ['1884'] is => True
#
#  SCHEMA METRIC:  defaultdict(<function calculate_schema_metrics.<locals>.<lambda> at 0x7f49e7c30720>, {'registrant_name': {'tp': 0, 'fp': 1, 'fn': 0}, 'registration_num': {'tp': 1, 'fp': 0, 'fn': 0}})
#
# Comparison result for pred_value: Italian Government Travel Office-e.n.i.t. and gt_value: ['Italian Government Travel Office-e.n.i.t 360 Post Street, Suite 801, San Francisco, Cal. Cal.'] is => False
#
# Comparison result for pred_value: 1884 and gt_value: ['1884'] is => True
#
#  SCHEMA METRIC:  defaultdict(<function calculate_schema_metrics.<locals>.<lambda> at 0x7f49e7c30720>, {'registrant_name': {'tp': 0, 'fp': 1, 'fn': 0}, 'registration_num': {'tp': 1, 'fp': 0, 'fn': 0}})
# 2025-02-21 14:20:47,543 - INFO - HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-21 14:20:47,548 - INFO - Raw Model output: Here are the extracted values in JSON format:
#
# ```
# {
#     "file_date": "1996-10-18",
#     "foreign_principle_name": "Government of Oman",
#     "registrant_name": "Verner, Liipfert, Bernhard, McPherson and Hand, Chartered",
#     "registration_num": "3712",
#     "signer_name": "Daniel Manatt",
#     "signer_title": ""
# }
# ```
# 2025-02-21 14:20:47,550 - INFO - Extracted Info List: [{'file_date': '1996-10-18', 'foreign_principle_name': 'Government of Oman', 'registrant_name': 'Verner, Liipfert, Bernhard, McPherson and Hand, Chartered', 'registration_num': '3712', 'signer_name': 'Daniel Manatt', 'signer_title': ''}]
# 2025-02-21 14:20:47,551 - INFO - Processing annotations for file: 19961018_DLA Piper US LLP_Amendment_Amendment.pdf
# 2025-02-21 14:20:47,557 - INFO - Experiment 0: Processing file 20020611_CMGRP, Inc._Amendment_Amendment.md
# 2025-02-21 14:20:47,565 - INFO - Generating chunks for file 20020611_CMGRP, Inc._Amendment_Amendment.md
# 2025-02-21 14:20:47,566 - INFO - Text length: 779, Chunk size: 2958
# 2025-02-21 14:20:47,567 - INFO - Generated chunk: ```markdown 1. Name of Registrant - BSMG Worldwide... with length 751
# 2025-02-21 14:20:47,569 - INFO - Generated 1 chunks with total text length 751
# 2025-02-21 14:20:47,570 - INFO - Generated 1 chunks with total prompt token size 120
# RAW PRED: [{'file_date': '1996-10-18', 'foreign_principle_name': 'Government of Oman', 'registrant_name': 'Verner, Liipfert, Bernhard, McPherson and Hand, Chartered', 'registration_num': '3712', 'signer_name': 'Daniel Manatt', 'signer_title': ''}]
#
# FLAT PRED:  [{'file_date': '1996-10-18', 'foreign_principle_name': 'Government of Oman', 'registrant_name': 'Verner, Liipfert, Bernhard, McPherson and Hand, Chartered', 'registration_num': '3712', 'signer_name': 'Daniel Manatt', 'signer_title': ''}]
#
# Reconciled PRED:  {'file_date': '1996-10-18', 'foreign_principle_name': 'Government of Oman', 'registrant_name': 'Verner, Liipfert, Bernhard, McPherson and Hand, Chartered', 'registration_num': '3712', 'signer_name': 'Daniel Manatt', 'signer_title': ''}
#
# initial_pred: {'file_date': '1996-10-18', 'foreign_principle_name': 'Government of Oman', 'registrant_name': 'Verner, Liipfert, Bernhard, McPherson and Hand, Chartered', 'registration_num': '3712', 'signer_name': 'Daniel Manatt', 'signer_title': ''}
#
# mapped_pred: {'file_date': '1996-10-18', 'foreign_principle_name': 'Government of Oman', 'registrant_name': 'Verner, Liipfert, Bernhard, McPherson and Hand, Chartered', 'registration_num': '3712', 'signer_name': 'Daniel Manatt', 'signer_title': ''}
#
# cleaned_pred: {'file_date': '1996-10-18', 'foreign_principle_name': 'Government Of Oman', 'registrant_name': 'Verner, Liipfert, Bernhard, Mcpherson And Hand, Chartered', 'registration_num': '3712', 'signer_name': 'Daniel Manatt', 'signer_title': ''}
#
# ground_truth_value: {'file_date': ['1\nday of October\n1996'], 'foreign_principle_name': '', 'registrant_name': ['Verner, Liipfert, Bernhard, McPherson\nand Hand, Chartered'], 'registration_num': ['3712'], 'signer_name': ['Daniel Manatt'], 'signer_title': ''}
# \cleaned_gt_value: {'file_date': ['1996-10-01'], 'foreign_principle_name': '', 'registrant_name': ['Verner, Liipfert, Bernhard, Mcpherson And Hand, Chartered'], 'registration_num': ['3712'], 'signer_name': ['Daniel Manatt'], 'signer_title': ''}
#
# Comparison result for pred_value: 1996-10-18 and gt_value: ['1\nday of October\n1996'] is => False
#
# Comparison result for pred_value: Verner, Liipfert, Bernhard, McPherson and Hand, Chartered and gt_value: ['Verner, Liipfert, Bernhard, McPherson\nand Hand, Chartered'] is => False
#
# Comparison result for pred_value: 3712 and gt_value: ['3712'] is => True
#
# Comparison result for pred_value: Daniel Manatt and gt_value: ['Daniel Manatt'] is => True
#
#  SCHEMA METRIC:  defaultdict(<function calculate_schema_metrics.<locals>.<lambda> at 0x7f49e7c30ea0>, {'file_date': {'tp': 0, 'fp': 1, 'fn': 0}, 'registrant_name': {'tp': 0, 'fp': 1, 'fn': 0}, 'registration_num': {'tp': 1, 'fp': 0, 'fn': 0}, 'signer_name': {'tp': 1, 'fp': 0, 'fn': 0}})
#
# Comparison result for pred_value: 1996-10-18 and gt_value: ['1\nday of October\n1996'] is => False
#
# Comparison result for pred_value: Verner, Liipfert, Bernhard, McPherson and Hand, Chartered and gt_value: ['Verner, Liipfert, Bernhard, McPherson\nand Hand, Chartered'] is => False
#
# Comparison result for pred_value: 3712 and gt_value: ['3712'] is => True
#
# Comparison result for pred_value: Daniel Manatt and gt_value: ['Daniel Manatt'] is => True
#
#  SCHEMA METRIC:  defaultdict(<function calculate_schema_metrics.<locals>.<lambda> at 0x7f49e7c30ea0>, {'file_date': {'tp': 0, 'fp': 1, 'fn': 0}, 'registrant_name': {'tp': 0, 'fp': 1, 'fn': 0}, 'registration_num': {'tp': 1, 'fp': 0, 'fn': 0}, 'signer_name': {'tp': 1, 'fp': 0, 'fn': 0}})
#
# Comparison result for pred_value: 1996-10-18 and gt_value: ['1996-10-01'] is => False
#
# Comparison result for pred_value: Verner, Liipfert, Bernhard, Mcpherson And Hand, Chartered and gt_value: ['Verner, Liipfert, Bernhard, Mcpherson And Hand, Chartered'] is => True
#
# Comparison result for pred_value: 3712 and gt_value: ['3712'] is => True
#
# Comparison result for pred_value: Daniel Manatt and gt_value: ['Daniel Manatt'] is => True
#
#  SCHEMA METRIC:  defaultdict(<function calculate_schema_metrics.<locals>.<lambda> at 0x7f49e7c30ea0>, {'file_date': {'tp': 0, 'fp': 1, 'fn': 0}, 'registrant_name': {'tp': 1, 'fp': 0, 'fn': 0}, 'registration_num': {'tp': 1, 'fp': 0, 'fn': 0}, 'signer_name': {'tp': 1, 'fp': 0, 'fn': 0}})
#
# initial_pred: {'file_date': '1996-10-18', 'foreign_principle_name': 'Government of Oman', 'registrant_name': 'Verner, Liipfert, Bernhard, McPherson and Hand, Chartered', 'registration_num': '3712', 'signer_name': 'Daniel Manatt', 'signer_title': ''}
#
# mapped_pred: {'file_date': '1996-10-18', 'foreign_principle_name': 'Government of Oman', 'registrant_name': 'Verner, Liipfert, Bernhard, McPherson and Hand, Chartered', 'registration_num': '3712', 'signer_name': 'Daniel Manatt', 'signer_title': ''}
#
# cleaned_pred: {'file_date': '1996-10-18', 'foreign_principle_name': 'Government Of Oman', 'registrant_name': 'Verner, Liipfert, Bernhard, Mcpherson And Hand, Chartered', 'registration_num': '3712', 'signer_name': 'Daniel Manatt', 'signer_title': ''}
#
# ground_truth_value: {'file_date': ['1\nday of October\n1996'], 'foreign_principle_name': '', 'registrant_name': ['Verner, Liipfert, Bernhard, McPherson\nand Hand, Chartered'], 'registration_num': ['3712'], 'signer_name': ['Daniel Manatt'], 'signer_title': ''}
# \cleaned_gt_value: {'file_date': ['1996-10-01'], 'foreign_principle_name': '', 'registrant_name': ['Verner, Liipfert, Bernhard, Mcpherson And Hand, Chartered'], 'registration_num': ['3712'], 'signer_name': ['Daniel Manatt'], 'signer_title': ''}
#
# Comparison result for pred_value: 1996-10-18 and gt_value: ['1\nday of October\n1996'] is => False
#
# Comparison result for pred_value: Verner, Liipfert, Bernhard, McPherson and Hand, Chartered and gt_value: ['Verner, Liipfert, Bernhard, McPherson\nand Hand, Chartered'] is => False
#
# Comparison result for pred_value: 3712 and gt_value: ['3712'] is => True
#
# Comparison result for pred_value: Daniel Manatt and gt_value: ['Daniel Manatt'] is => True
#
#  SCHEMA METRIC:  defaultdict(<function calculate_schema_metrics.<locals>.<lambda> at 0x7f49e7c30ea0>, {'file_date': {'tp': 0, 'fp': 1, 'fn': 0}, 'registrant_name': {'tp': 0, 'fp': 1, 'fn': 0}, 'registration_num': {'tp': 1, 'fp': 0, 'fn': 0}, 'signer_name': {'tp': 1, 'fp': 0, 'fn': 0}})
#
# Comparison result for pred_value: 1996-10-18 and gt_value: ['1\nday of October\n1996'] is => False
#
# Comparison result for pred_value: Verner, Liipfert, Bernhard, McPherson and Hand, Chartered and gt_value: ['Verner, Liipfert, Bernhard, McPherson\nand Hand, Chartered'] is => False
#
# Comparison result for pred_value: 3712 and gt_value: ['3712'] is => True
#
# Comparison result for pred_value: Daniel Manatt and gt_value: ['Daniel Manatt'] is => True
#
#  SCHEMA METRIC:  defaultdict(<function calculate_schema_metrics.<locals>.<lambda> at 0x7f49e7c30ea0>, {'file_date': {'tp': 0, 'fp': 1, 'fn': 0}, 'registrant_name': {'tp': 0, 'fp': 1, 'fn': 0}, 'registration_num': {'tp': 1, 'fp': 0, 'fn': 0}, 'signer_name': {'tp': 1, 'fp': 0, 'fn': 0}})
#
# Comparison result for pred_value: 1996-10-18 and gt_value: ['1996-10-01'] is => False
#
# Comparison result for pred_value: Verner, Liipfert, Bernhard, Mcpherson And Hand, Chartered and gt_value: ['Verner, Liipfert, Bernhard, Mcpherson And Hand, Chartered'] is => True
#
# Comparison result for pred_value: 3712 and gt_value: ['3712'] is => True
#
# Comparison result for pred_value: Daniel Manatt and gt_value: ['Daniel Manatt'] is => True
#
#  SCHEMA METRIC:  defaultdict(<function calculate_schema_metrics.<locals>.<lambda> at 0x7f49e7c30ea0>, {'file_date': {'tp': 0, 'fp': 1, 'fn': 0}, 'registrant_name': {'tp': 1, 'fp': 0, 'fn': 0}, 'registration_num': {'tp': 1, 'fp': 0, 'fn': 0}, 'signer_name': {'tp': 1, 'fp': 0, 'fn': 0}})
#
# initial_pred: {'file_date': '1996-10-18', 'foreign_principle_name': 'Government of Oman', 'registrant_name': 'Verner, Liipfert, Bernhard, McPherson and Hand, Chartered', 'registration_num': '3712', 'signer_name': 'Daniel Manatt', 'signer_title': ''}
#
# mapped_pred: {'file_date': '1996-10-18', 'foreign_principle_name': 'Government of Oman', 'registrant_name': 'Verner, Liipfert, Bernhard, McPherson and Hand, Chartered', 'registration_num': '3712', 'signer_name': 'Daniel Manatt', 'signer_title': ''}
#
# cleaned_pred: {'file_date': '1996-10-18', 'foreign_principle_name': 'Government Of Oman', 'registrant_name': 'Verner, Liipfert, Bernhard, Mcpherson And Hand, Chartered', 'registration_num': '3712', 'signer_name': 'Daniel Manatt', 'signer_title': ''}
#
# ground_truth_value: {'file_date': ['1\nday of October\n1996'], 'foreign_principle_name': '', 'registrant_name': ['Verner, Liipfert, Bernhard, McPherson\nand Hand, Chartered'], 'registration_num': ['3712'], 'signer_name': ['Daniel Manatt'], 'signer_title': ''}
# \cleaned_gt_value: {'file_date': ['1996-10-01'], 'foreign_principle_name': '', 'registrant_name': ['Verner, Liipfert, Bernhard, Mcpherson And Hand, Chartered'], 'registration_num': ['3712'], 'signer_name': ['Daniel Manatt'], 'signer_title': ''}
#
# Comparison result for pred_value: 1996-10-18 and gt_value: ['1\nday of October\n1996'] is => False
#
# Comparison result for pred_value: Verner, Liipfert, Bernhard, McPherson and Hand, Chartered and gt_value: ['Verner, Liipfert, Bernhard, McPherson\nand Hand, Chartered'] is => True
#
# Comparison result for pred_value: 3712 and gt_value: ['3712'] is => True
#
# Comparison result for pred_value: Daniel Manatt and gt_value: ['Daniel Manatt'] is => True
#
#  SCHEMA METRIC:  defaultdict(<function calculate_schema_metrics.<locals>.<lambda> at 0x7f49e7c30ea0>, {'file_date': {'tp': 0, 'fp': 1, 'fn': 0}, 'registrant_name': {'tp': 1, 'fp': 0, 'fn': 0}, 'registration_num': {'tp': 1, 'fp': 0, 'fn': 0}, 'signer_name': {'tp': 1, 'fp': 0, 'fn': 0}})
#
# Comparison result for pred_value: 1996-10-18 and gt_value: ['1\nday of October\n1996'] is => False
#
# Comparison result for pred_value: Verner, Liipfert, Bernhard, McPherson and Hand, Chartered and gt_value: ['Verner, Liipfert, Bernhard, McPherson\nand Hand, Chartered'] is => True
#
# Comparison result for pred_value: 3712 and gt_value: ['3712'] is => True
#
# Comparison result for pred_value: Daniel Manatt and gt_value: ['Daniel Manatt'] is => True
#
#  SCHEMA METRIC:  defaultdict(<function calculate_schema_metrics.<locals>.<lambda> at 0x7f49e7c30ea0>, {'file_date': {'tp': 0, 'fp': 1, 'fn': 0}, 'registrant_name': {'tp': 1, 'fp': 0, 'fn': 0}, 'registration_num': {'tp': 1, 'fp': 0, 'fn': 0}, 'signer_name': {'tp': 1, 'fp': 0, 'fn': 0}})
#
# Comparison result for pred_value: 1996-10-18 and gt_value: ['1996-10-01'] is => True
#
# Comparison result for pred_value: Verner, Liipfert, Bernhard, Mcpherson And Hand, Chartered and gt_value: ['Verner, Liipfert, Bernhard, Mcpherson And Hand, Chartered'] is => True
#
# Comparison result for pred_value: 3712 and gt_value: ['3712'] is => True
#
# Comparison result for pred_value: Daniel Manatt and gt_value: ['Daniel Manatt'] is => True
#
#  SCHEMA METRIC:  defaultdict(<function calculate_schema_metrics.<locals>.<lambda> at 0x7f49e7c30ea0>, {'file_date': {'tp': 1, 'fp': 0, 'fn': 0}, 'registrant_name': {'tp': 1, 'fp': 0, 'fn': 0}, 'registration_num': {'tp': 1, 'fp': 0, 'fn': 0}, 'signer_name': {'tp': 1, 'fp': 0, 'fn': 0}})
# 2025-02-21 14:20:48,372 - INFO - HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-21 14:20:48,376 - INFO - Raw Model output: {
# "file_date": "3/28/02",
# "foreign_principle_name": "",
# "registrant_name": "BSMG Worldwide",
# "registration_num": "3911",
# "signer_name": "Lance Morgan",
# "signer_title": ""
# }
# 2025-02-21 14:20:48,378 - INFO - Extracted Info List: [{'file_date': '3/28/02', 'foreign_principle_name': '', 'registrant_name': 'BSMG Worldwide', 'registration_num': '3911', 'signer_name': 'Lance Morgan', 'signer_title': ''}]
# ...
#
# initial_pred: {'file_date': '04/24/2012', 'foreign_principle_name': 'Secretaria de Economia (Secretariat of Economy)', 'registrant_name': 'Pillsbury Winthrop Shaw Pittman LLP', 'registration_num': '5198', 'signer_name': 'Stephan E. Becker', 'signer_title': ''}
#
# mapped_pred: {'file_date': '04/24/2012', 'foreign_principle_name': 'Secretaria de Economia (Secretariat of Economy)', 'registrant_name': 'Pillsbury Winthrop Shaw Pittman LLP', 'registration_num': '5198', 'signer_name': 'Stephan E. Becker', 'signer_title': ''}
#
# cleaned_pred: {'file_date': '2012-04-24', 'foreign_principle_name': 'Secretaria De Economia (secretariat Of Economy)', 'registrant_name': 'Pillsbury Winthrop Shaw Pittman Llp', 'registration_num': '5198', 'signer_name': 'Stephan E. Becker', 'signer_title': ''}
#
# ground_truth_value: {'file_date': ['April 24, 2012'], 'foreign_principle_name': '', 'registrant_name': ['Pillsbury Winthrop Shaw Pittman LLP'], 'registration_num': ['5198'], 'signer_name': ['Stephan E. Becker'], 'signer_title': ''}
# \cleaned_gt_value: {'file_date': ['2012-04-24'], 'foreign_principle_name': '', 'registrant_name': ['Pillsbury Winthrop Shaw Pittman Llp'], 'registration_num': ['5198'], 'signer_name': ['Stephan E. Becker'], 'signer_title': ''}
#
# Comparison result for pred_value: 04/24/2012 and gt_value: ['April 24, 2012'] is => False
#
# Comparison result for pred_value: Pillsbury Winthrop Shaw Pittman LLP and gt_value: ['Pillsbury Winthrop Shaw Pittman LLP'] is => True
#
# Comparison result for pred_value: 5198 and gt_value: ['5198'] is => True
#
# Comparison result for pred_value: Stephan E. Becker and gt_value: ['Stephan E. Becker'] is => True
#
#  SCHEMA METRIC:  defaultdict(<function calculate_schema_metrics.<locals>.<lambda> at 0x7f49e7c33560>, {'file_date': {'tp': 0, 'fp': 1, 'fn': 0}, 'registrant_name': {'tp': 1, 'fp': 0, 'fn': 0}, 'registration_num': {'tp': 1, 'fp': 0, 'fn': 0}, 'signer_name': {'tp': 1, 'fp': 0, 'fn': 0}})
#
# Comparison result for pred_value: 04/24/2012 and gt_value: ['April 24, 2012'] is => False
#
# Comparison result for pred_value: Pillsbury Winthrop Shaw Pittman LLP and gt_value: ['Pillsbury Winthrop Shaw Pittman LLP'] is => True
#
# Comparison result for pred_value: 5198 and gt_value: ['5198'] is => True
#
# Comparison result for pred_value: Stephan E. Becker and gt_value: ['Stephan E. Becker'] is => True
#
#  SCHEMA METRIC:  defaultdict(<function calculate_schema_metrics.<locals>.<lambda> at 0x7f49e7c33560>, {'file_date': {'tp': 0, 'fp': 1, 'fn': 0}, 'registrant_name': {'tp': 1, 'fp': 0, 'fn': 0}, 'registration_num': {'tp': 1, 'fp': 0, 'fn': 0}, 'signer_name': {'tp': 1, 'fp': 0, 'fn': 0}})
#
# Comparison result for pred_value: 2012-04-24 and gt_value: ['2012-04-24'] is => True
#
# Comparison result for pred_value: Pillsbury Winthrop Shaw Pittman Llp and gt_value: ['Pillsbury Winthrop Shaw Pittman Llp'] is => True
#
# Comparison result for pred_value: 5198 and gt_value: ['5198'] is => True
#
# Comparison result for pred_value: Stephan E. Becker and gt_value: ['Stephan E. Becker'] is => True
#
#  SCHEMA METRIC:  defaultdict(<function calculate_schema_metrics.<locals>.<lambda> at 0x7f49e7c33560>, {'file_date': {'tp': 1, 'fp': 0, 'fn': 0}, 'registrant_name': {'tp': 1, 'fp': 0, 'fn': 0}, 'registration_num': {'tp': 1, 'fp': 0, 'fn': 0}, 'signer_name': {'tp': 1, 'fp': 0, 'fn': 0}})
# 2025-02-21 14:20:55,843 - INFO - HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-21 14:20:55,847 - INFO - Raw Model output: {"file_date": "09/01/2017", "foreign_principle_name": "", "registrant_name": "Bryan Cave LLP", "registration_num": "6356", "signer_name": "LaDawn Naegle", "signer_title": "Office Managing Partner"}
# 2025-02-21 14:20:55,849 - INFO - Extracted Info List: [{'file_date': '09/01/2017', 'foreign_principle_name': '', 'registrant_name': 'Bryan Cave LLP', 'registration_num': '6356', 'signer_name': 'LaDawn Naegle', 'signer_title': 'Office Managing Partner'}]
# 2025-02-21 14:20:55,851 - INFO - Processing annotations for file: 20170901_Bryan Cave, LLP_Amendment_Amendment.pdf
# 2025-02-21 14:20:55,856 - INFO - Experiment 0: Processing file 20171116_Wiley Rein, LLP_Amendment_Amendment.md
# 2025-02-21 14:20:55,870 - INFO - Generating chunks for file 20171116_Wiley Rein, LLP_Amendment_Amendment.md
# 2025-02-21 14:20:55,872 - INFO - Text length: 6560, Chunk size: 2958
# 2025-02-21 14:20:55,874 - INFO - Generated chunk: ```markdown Received by NSD/FARA Registration Unit... with length 6403
# 2025-02-21 14:20:55,876 - INFO - Generated 1 chunks with total text length 6403
# 2025-02-21 14:20:55,878 - INFO - Generated 1 chunks with total prompt token size 962
# 2025-02-21 14:20:55,879 - INFO - Rate limit reached. Waiting for 34.95 seconds.
# RAW PRED: [{'file_date': '09/01/2017', 'foreign_principle_name': '', 'registrant_name': 'Bryan Cave LLP', 'registration_num': '6356', 'signer_name': 'LaDawn Naegle', 'signer_title': 'Office Managing Partner'}]
#
# FLAT PRED:  [{'file_date': '09/01/2017', 'foreign_principle_name': '', 'registrant_name': 'Bryan Cave LLP', 'registration_num': '6356', 'signer_name': 'LaDawn Naegle', 'signer_title': 'Office Managing Partner'}]
#
# Reconciled PRED:  {'file_date': '09/01/2017', 'foreign_principle_name': '', 'registrant_name': 'Bryan Cave LLP', 'registration_num': '6356', 'signer_name': 'LaDawn Naegle', 'signer_title': 'Office Managing Partner'}
#
# initial_pred: {'file_date': '09/01/2017', 'foreign_principle_name': '', 'registrant_name': 'Bryan Cave LLP', 'registration_num': '6356', 'signer_name': 'LaDawn Naegle', 'signer_title': 'Office Managing Partner'}
#
# mapped_pred: {'file_date': '09/01/2017', 'foreign_principle_name': '', 'registrant_name': 'Bryan Cave LLP', 'registration_num': '6356', 'signer_name': 'LaDawn Naegle', 'signer_title': 'Office Managing Partner'}
#
# cleaned_pred: {'file_date': '2017-09-01', 'foreign_principle_name': '', 'registrant_name': 'Bryan Cave Llp', 'registration_num': '6356', 'signer_name': 'Ladawn Naegle', 'signer_title': 'office managing partner'}
#
# ground_truth_value: {'file_date': ['September 1, 2017'], 'foreign_principle_name': '', 'registrant_name': ['Bryan Cave LLP'], 'registration_num': ['6356'], 'signer_name': ['LaDawn Naegle,'], 'signer_title': ['Office Managing Partner']}
# \cleaned_gt_value: {'file_date': ['2017-09-01'], 'foreign_principle_name': '', 'registrant_name': ['Bryan Cave Llp'], 'registration_num': ['6356'], 'signer_name': ['Ladawn Naegle,'], 'signer_title': ['office managing partner']}
#
# Comparison result for pred_value: 09/01/2017 and gt_value: ['September 1, 2017'] is => False
#
# Comparison result for pred_value: Bryan Cave LLP and gt_value: ['Bryan Cave LLP'] is => True
#
# Comparison result for pred_value: 6356 and gt_value: ['6356'] is => True
#
# Comparison result for pred_value: LaDawn Naegle and gt_value: ['LaDawn Naegle,'] is => False
#
# Comparison result for pred_value: Office Managing Partner and gt_value: ['Office Managing Partner'] is => True
#
#  SCHEMA METRIC:  defaultdict(<function calculate_schema_metrics.<locals>.<lambda> at 0x7f49e7c31120>, {'file_date': {'tp': 0, 'fp': 1, 'fn': 0}, 'registrant_name': {'tp': 1, 'fp': 0, 'fn': 0}, 'registration_num': {'tp': 1, 'fp': 0, 'fn': 0}, 'signer_name': {'tp': 0, 'fp': 1, 'fn': 0}, 'signer_title': {'tp': 1, 'fp': 0, 'fn': 0}})
#
# Comparison result for pred_value: 09/01/2017 and gt_value: ['September 1, 2017'] is => False
#
# Comparison result for pred_value: Bryan Cave LLP and gt_value: ['Bryan Cave LLP'] is => True
#
# Comparison result for pred_value: 6356 and gt_value: ['6356'] is => True
#
# Comparison result for pred_value: LaDawn Naegle and gt_value: ['LaDawn Naegle,'] is => False
#
# Comparison result for pred_value: Office Managing Partner and gt_value: ['Office Managing Partner'] is => True
#
#  SCHEMA METRIC:  defaultdict(<function calculate_schema_metrics.<locals>.<lambda> at 0x7f49e7c31120>, {'file_date': {'tp': 0, 'fp': 1, 'fn': 0}, 'registrant_name': {'tp': 1, 'fp': 0, 'fn': 0}, 'registration_num': {'tp': 1, 'fp': 0, 'fn': 0}, 'signer_name': {'tp': 0, 'fp': 1, 'fn': 0}, 'signer_title': {'tp': 1, 'fp': 0, 'fn': 0}})
#
# Comparison result for pred_value: 2017-09-01 and gt_value: ['2017-09-01'] is => True
#
# Comparison result for pred_value: Bryan Cave Llp and gt_value: ['Bryan Cave Llp'] is => True
#
# Comparison result for pred_value: 6356 and gt_value: ['6356'] is => True
#
# Comparison result for pred_value: Ladawn Naegle and gt_value: ['Ladawn Naegle,'] is => False
#
# Comparison result for pred_value: office managing partner and gt_value: ['office managing partner'] is => True
#
#  SCHEMA METRIC:  defaultdict(<function calculate_schema_metrics.<locals>.<lambda> at 0x7f49e7c31120>, {'file_date': {'tp': 1, 'fp': 0, 'fn': 0}, 'registrant_name': {'tp': 1, 'fp': 0, 'fn': 0}, 'registration_num': {'tp': 1, 'fp': 0, 'fn': 0}, 'signer_name': {'tp': 0, 'fp': 1, 'fn': 0}, 'signer_title': {'tp': 1, 'fp': 0, 'fn': 0}})
#
# initial_pred: {'file_date': '09/01/2017', 'foreign_principle_name': '', 'registrant_name': 'Bryan Cave LLP', 'registration_num': '6356', 'signer_name': 'LaDawn Naegle', 'signer_title': 'Office Managing Partner'}
#
# mapped_pred: {'file_date': '09/01/2017', 'foreign_principle_name': '', 'registrant_name': 'Bryan Cave LLP', 'registration_num': '6356', 'signer_name': 'LaDawn Naegle', 'signer_title': 'Office Managing Partner'}
#
# cleaned_pred: {'file_date': '2017-09-01', 'foreign_principle_name': '', 'registrant_name': 'Bryan Cave Llp', 'registration_num': '6356', 'signer_name': 'Ladawn Naegle', 'signer_title': 'office managing partner'}
#
# ground_truth_value: {'file_date': ['September 1, 2017'], 'foreign_principle_name': '', 'registrant_name': ['Bryan Cave LLP'], 'registration_num': ['6356'], 'signer_name': ['LaDawn Naegle,'], 'signer_title': ['Office Managing Partner']}
# \cleaned_gt_value: {'file_date': ['2017-09-01'], 'foreign_principle_name': '', 'registrant_name': ['Bryan Cave Llp'], 'registration_num': ['6356'], 'signer_name': ['Ladawn Naegle,'], 'signer_title': ['office managing partner']}
#
# Comparison result for pred_value: 09/01/2017 and gt_value: ['September 1, 2017'] is => False
#
# Comparison result for pred_value: Bryan Cave LLP and gt_value: ['Bryan Cave LLP'] is => True
#
# Comparison result for pred_value: 6356 and gt_value: ['6356'] is => True
#
# Comparison result for pred_value: LaDawn Naegle and gt_value: ['LaDawn Naegle,'] is => False
#
# Comparison result for pred_value: Office Managing Partner and gt_value: ['Office Managing Partner'] is => True
#
#  SCHEMA METRIC:  defaultdict(<function calculate_schema_metrics.<locals>.<lambda> at 0x7f49e7c31120>, {'file_date': {'tp': 0, 'fp': 1, 'fn': 0}, 'registrant_name': {'tp': 1, 'fp': 0, 'fn': 0}, 'registration_num': {'tp': 1, 'fp': 0, 'fn': 0}, 'signer_name': {'tp': 0, 'fp': 1, 'fn': 0}, 'signer_title': {'tp': 1, 'fp': 0, 'fn': 0}})
#
# Comparison result for pred_value: 09/01/2017 and gt_value: ['September 1, 2017'] is => False
#
# Comparison result for pred_value: Bryan Cave LLP and gt_value: ['Bryan Cave LLP'] is => True
#
# Comparison result for pred_value: 6356 and gt_value: ['6356'] is => True
#
# Comparison result for pred_value: LaDawn Naegle and gt_value: ['LaDawn Naegle,'] is => False
#
# Comparison result for pred_value: Office Managing Partner and gt_value: ['Office Managing Partner'] is => True
#
#  SCHEMA METRIC:  defaultdict(<function calculate_schema_metrics.<locals>.<lambda> at 0x7f49e7c31120>, {'file_date': {'tp': 0, 'fp': 1, 'fn': 0}, 'registrant_name': {'tp': 1, 'fp': 0, 'fn': 0}, 'registration_num': {'tp': 1, 'fp': 0, 'fn': 0}, 'signer_name': {'tp': 0, 'fp': 1, 'fn': 0}, 'signer_title': {'tp': 1, 'fp': 0, 'fn': 0}})
#
# Comparison result for pred_value: 2017-09-01 and gt_value: ['2017-09-01'] is => True
#
# Comparison result for pred_value: Bryan Cave Llp and gt_value: ['Bryan Cave Llp'] is => True
#
# Comparison result for pred_value: 6356 and gt_value: ['6356'] is => True
#
# Comparison result for pred_value: Ladawn Naegle and gt_value: ['Ladawn Naegle,'] is => False
#
# Comparison result for pred_value: office managing partner and gt_value: ['office managing partner'] is => True
#
#  SCHEMA METRIC:  defaultdict(<function calculate_schema_metrics.<locals>.<lambda> at 0x7f49e7c31120>, {'file_date': {'tp': 1, 'fp': 0, 'fn': 0}, 'registrant_name': {'tp': 1, 'fp': 0, 'fn': 0}, 'registration_num': {'tp': 1, 'fp': 0, 'fn': 0}, 'signer_name': {'tp': 0, 'fp': 1, 'fn': 0}, 'signer_title': {'tp': 1, 'fp': 0, 'fn': 0}})
#
# initial_pred: {'file_date': '09/01/2017', 'foreign_principle_name': '', 'registrant_name': 'Bryan Cave LLP', 'registration_num': '6356', 'signer_name': 'LaDawn Naegle', 'signer_title': 'Office Managing Partner'}
#
# mapped_pred: {'file_date': '09/01/2017', 'foreign_principle_name': '', 'registrant_name': 'Bryan Cave LLP', 'registration_num': '6356', 'signer_name': 'LaDawn Naegle', 'signer_title': 'Office Managing Partner'}
#
# cleaned_pred: {'file_date': '2017-09-01', 'foreign_principle_name': '', 'registrant_name': 'Bryan Cave Llp', 'registration_num': '6356', 'signer_name': 'Ladawn Naegle', 'signer_title': 'office managing partner'}
#
# ground_truth_value: {'file_date': ['September 1, 2017'], 'foreign_principle_name': '', 'registrant_name': ['Bryan Cave LLP'], 'registration_num': ['6356'], 'signer_name': ['LaDawn Naegle,'], 'signer_title': ['Office Managing Partner']}
# \cleaned_gt_value: {'file_date': ['2017-09-01'], 'foreign_principle_name': '', 'registrant_name': ['Bryan Cave Llp'], 'registration_num': ['6356'], 'signer_name': ['Ladawn Naegle,'], 'signer_title': ['office managing partner']}
#
# Comparison result for pred_value: 09/01/2017 and gt_value: ['September 1, 2017'] is => False
#
# Comparison result for pred_value: Bryan Cave LLP and gt_value: ['Bryan Cave LLP'] is => True
#
# Comparison result for pred_value: 6356 and gt_value: ['6356'] is => True
#
# Comparison result for pred_value: LaDawn Naegle and gt_value: ['LaDawn Naegle,'] is => True
#
# Comparison result for pred_value: Office Managing Partner and gt_value: ['Office Managing Partner'] is => True
#
#  SCHEMA METRIC:  defaultdict(<function calculate_schema_metrics.<locals>.<lambda> at 0x7f49e7c31120>, {'file_date': {'tp': 0, 'fp': 1, 'fn': 0}, 'registrant_name': {'tp': 1, 'fp': 0, 'fn': 0}, 'registration_num': {'tp': 1, 'fp': 0, 'fn': 0}, 'signer_name': {'tp': 1, 'fp': 0, 'fn': 0}, 'signer_title': {'tp': 1, 'fp': 0, 'fn': 0}})
#
# Comparison result for pred_value: 09/01/2017 and gt_value: ['September 1, 2017'] is => False
#
# Comparison result for pred_value: Bryan Cave LLP and gt_value: ['Bryan Cave LLP'] is => True
#
# Comparison result for pred_value: 6356 and gt_value: ['6356'] is => True
#
# Comparison result for pred_value: LaDawn Naegle and gt_value: ['LaDawn Naegle,'] is => True
#
# Comparison result for pred_value: Office Managing Partner and gt_value: ['Office Managing Partner'] is => True
#
#  SCHEMA METRIC:  defaultdict(<function calculate_schema_metrics.<locals>.<lambda> at 0x7f49e7c31120>, {'file_date': {'tp': 0, 'fp': 1, 'fn': 0}, 'registrant_name': {'tp': 1, 'fp': 0, 'fn': 0}, 'registration_num': {'tp': 1, 'fp': 0, 'fn': 0}, 'signer_name': {'tp': 1, 'fp': 0, 'fn': 0}, 'signer_title': {'tp': 1, 'fp': 0, 'fn': 0}})
#
# Comparison result for pred_value: 2017-09-01 and gt_value: ['2017-09-01'] is => True
#
# Comparison result for pred_value: Bryan Cave Llp and gt_value: ['Bryan Cave Llp'] is => True
#
# Comparison result for pred_value: 6356 and gt_value: ['6356'] is => True
#
# Comparison result for pred_value: Ladawn Naegle and gt_value: ['Ladawn Naegle,'] is => True
#
# Comparison result for pred_value: office managing partner and gt_value: ['office managing partner'] is => True
#
#  SCHEMA METRIC:  defaultdict(<function calculate_schema_metrics.<locals>.<lambda> at 0x7f49e7c31120>, {'file_date': {'tp': 1, 'fp': 0, 'fn': 0}, 'registrant_name': {'tp': 1, 'fp': 0, 'fn': 0}, 'registration_num': {'tp': 1, 'fp': 0, 'fn': 0}, 'signer_name': {'tp': 1, 'fp': 0, 'fn': 0}, 'signer_title': {'tp': 1, 'fp': 0, 'fn': 0}})

# %%
batch_file_paths = split_jsonl_file(output_file, max_size=209715200, max_lines=1000)  # Adjust max_lines as needed
batch_ids = send_batch_requests(batch_file_paths)
print(f"Batch IDs: {batch_ids}")
# Out:
# 2024-12-10 19:27:23,685 - INFO - HTTP Request: POST https://api.openai.com/v1/files "HTTP/1.1 200 OK"
# 2024-12-10 19:27:24,692 - INFO - HTTP Request: POST https://api.openai.com/v1/batches "HTTP/1.1 200 OK"
# 2024-12-10 19:27:25,467 - INFO - HTTP Request: POST https://api.openai.com/v1/files "HTTP/1.1 200 OK"
# 2024-12-10 19:27:26,984 - INFO - HTTP Request: POST https://api.openai.com/v1/batches "HTTP/1.1 200 OK"
# Batch IDs: ['batch_6758961c868c8191b4364aa432c93e5b', 'batch_6758961ed0d081919ba1826826f5af80']

# %%
if __name__ == "__main__":
    all_filename_mappings, all_output_data = load_experiment_results(base_output_directory)
    print("DONE")

# %%
ground_truth_annotations, _ = load_dataset(dataset_path)
logging.info("Loaded ground truth annotations")
response_dir = os.path.join(base_output_directory, "responses")

retrieve_and_process_batch_results(response_dir, ground_truth_annotations, all_filename_mappings, all_output_data, base_output_directory)

# %% [markdown]
# ### Concatanate all experıment result ınto one csv fıle and perform aggregatıon

# %%
import os
import pandas as pd
import logging

def concatenate_experiments(experiments_dir, output_filename):
    try:
        # Initialize an empty list to store DataFrames
        dataframes = []

        # Check if the experiments directory exists
        if not os.path.exists(experiments_dir):
            logging.error(f"Experiments directory not found: {full_experiments_path}")
            return None

        # Iterate over each file in the experiments directory
        for filename in os.listdir(experiments_dir):
            # Check if the file is a CSV
            if filename.endswith(".csv"):
                file_path = os.path.join(experiments_dir, filename)

                # Read the CSV file into a DataFrame
                df = pd.read_csv(file_path)

                # Add a column for the experiment ID derived from the filename
                experiment_id = os.path.splitext(filename)[0]
                df['experiment_id'] = experiment_id

                # Append the DataFrame to the list
                dataframes.append(df)

                logging.info(f"Loaded data from {file_path}")

        # Concatenate all DataFrames in the list into a single DataFrame
        combined_df = pd.concat(dataframes, ignore_index=True)

        # Save the combined DataFrame to a CSV file
        combined_df.to_csv(output_filename, index=False)

        logging.info(f"All experiment data concatenated and saved to {output_filename}")
        print(f"All experiment data concatenated and saved to {output_filename}")
        return output_filename

    except Exception as e:
        logging.error(f"Error while concatenating experiment data: {e}")
        print(f"Error while concatenating experiment data: {e}")
        return None

# Example usage
experiments_dir = os.path.join(base_output_directory, 'experiments')
output_filename = path.join(base_output_directory, 'gpt4_Markdown_gpt3-metrics.csv')

concatenate_experiments(experiments_dir, output_filename)

# %%
import pandas as pd
import json
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
from modules.postprocessing import *
from modules.data_processing import *
from modules.metrics import *
from config_llama import *

df = pd.read_csv(output_filename)
grouped = df.groupby('experiment_id')

aggregated_results = grouped.agg({
    'precision_before': 'mean',
    'precision_after': 'mean',
    'recall_before': 'mean',
    'recall_after': 'mean',
    'f1_before': 'mean',
    'f1_after': 'mean',
    'accuracy_before': 'mean',
    'accuracy_after': 'mean'
}).reset_index()

output_csv_path = path.join(base_output_directory, 'gpt4_Markdown_gpt3-results.csv')
aggregated_results.to_csv(output_csv_path, index=False)
print("New CSV file created successfully.")
# Out:
# New CSV file created successfully.
